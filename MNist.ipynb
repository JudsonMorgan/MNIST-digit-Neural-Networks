# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_probability as tfp
from tensorflow import keras
import tensorflow as tf
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
#load dataset
mnist = keras.datasets.mnist
(X_train, y_train), (X_test,y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28), (60000,), (10000,))

# %%
#view the dataset
print(X_train[2,23,23])
# Out:
# 0

# %%
plt.figure()
plt.imshow(X_train[255])
plt.grid(False)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(128, activation='sigmoid'),
                          keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss="sparse_categorical_crossentropy",
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3996 - accuracy: 0.8959
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1960 - accuracy: 0.9435
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1435 - accuracy: 0.9584
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1122 - accuracy: 0.9676
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0909 - accuracy: 0.9740
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0747 - accuracy: 0.9787
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0624 - accuracy: 0.9825
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0528 - accuracy: 0.9853
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0446 - accuracy: 0.9881
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0373 - accuracy: 0.9905

# %%
result = model.evaluate(X_test, y_test)
print(result)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0785 - accuracy: 0.9756
# [0.0785217136144638, 0.975600004196167]

# %%
#make some prediction
prediction = model.predict(X_test)
print(prediction[:10])
# Out:
# [[6.86351359e-06 6.83808196e-07 8.81445958e-05 4.61591058e-04
#   8.24516704e-08 5.33951197e-06 1.59658164e-09 9.99417186e-01
#   4.89119293e-06 1.52900011e-05]
#  [1.74163790e-06 2.82422523e-04 9.99689579e-01 5.81897939e-06
#   2.15227697e-10 1.89649763e-05 1.39871963e-06 3.29458882e-09
#   5.36078133e-08 2.49405896e-09]
#  [3.51259430e-08 9.99322891e-01 4.04403196e-04 1.26844789e-05
#   4.86947192e-06 4.72617603e-06 9.11853022e-06 2.02887808e-04
#   3.78145451e-05 5.43377780e-07]
#  [9.99332368e-01 1.64979085e-07 6.01666907e-05 1.57177305e-06
#   1.88745471e-05 6.28640555e-05 2.81370361e-04 1.39846525e-04
#   7.71535724e-07 1.02074155e-04]
#  [3.08340691e-06 6.79578207e-08 1.54431546e-05 1.91351859e-07
#   9.96962965e-01 8.82207405e-06 7.98010387e-06 8.12892249e-05
#   3.80975325e-05 2.88204406e-03]
#  [1.55716116e-08 9.99634981e-01 8.20033983e-06 4.80362678e-06
#   2.83384816e-06 1.39313926e-07 8.82185134e-08 3.46388319e-04
#   1.74217064e-06 8.44445481e-07]
#  [6.17561454e-07 1.81403755e-06 2.43312911e-06 1.41015323e-06
#   9.79932785e-01 7.14134949e-05 1.21621940e-06 2.52260215e-04
#   1.88570470e-02 8.79041210e-04]
#  [1.83914572e-09 5.18916022e-05 2.64621158e-05 8.96338955e-04
#   1.13789900e-03 6.86494241e-05 6.45196163e-09 3.61459229e-06
#   8.65617494e-06 9.97806489e-01]
#  [7.53253407e-04 6.76790442e-05 4.37911181e-03 6.44525289e-06
#   3.25292523e-04 2.54104380e-02 9.59097505e-01 1.92585208e-06
#   9.20347217e-03 7.54904177e-04]
#  [4.69447571e-07 2.10000888e-08 1.18204628e-06 4.01005445e-06
#   2.58668303e-03 5.25809526e-07 5.80885695e-09 6.92102243e-04
#   2.92016543e-04 9.96422946e-01]]

# %%
plt.figure()
plt.imshow(X_test[255])
plt.colorbar()
plt.grid(False)
plt.show()
